# %%
import pandas as pd

# %%
data=[10,20,30,40,50,60]
df=pd.DataFrame(data)

# %%
df
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
# 5  60

# %%
data=[['Neel',80],['Yogesh',23]]
df=pd.DataFrame(data)

# %%
df
# Out:
#         0   1
# 0    Neel  80
# 1  Yogesh  23

# %%
data=[['Neel',80],['Yogesh',23]]
df=pd.DataFrame(data,columns=['Name','Age'])

# %%
df
# Out:
#      Name  Age
# 0    Neel   80
# 1  Yogesh   23

# %%
del df['Age']
df
# Out:
#      Name
# 0    Neel
# 1  Yogesh

# %%
df.to_json('student.json')

# %%
pd.read_json('student.json')
# Out:
#      Name
# 0    Neel
# 1  Yogesh

# %%
url = "https://api.exchangerate-api.com/v4/latest/USD"
import requests
from pandas.io.json import json_normalize
df = pd.read_json(url)

# %%
type(df['rates'])
# Out:
# pandas.core.series.Series

# %%
type(df[['date', 'rates']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[[0,5],[1,3]]
# Out:
#                           WARNING_UPGRADE_TO_V6 base
# AED  https://www.exchangerate-api.com/docs/free  USD
# AOA  https://www.exchangerate-api.com/docs/free  USD

# %%
df.sort_values(by='Marks')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 df.sort_values(by='Marks')
#
# File C:\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:6904, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6900 elif len(by):
#    6901     # len(by) == 1
#    6903     by = by[0]
# -> 6904     k = self._get_label_or_level_values(by, axis=axis)
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams.updata({'font.size':20,'figure.figsize:(10,8)'})
# Out:
#   Cell In [23], line 1
#     plt.rcParams.updata({'font.size':20,'figure.figsize:(10,8)'})
#                                                               ^
# SyntaxError: ':' expected after dictionary key

# %%
data=[['tom',10,50],['nick',16,58]]
df=pd.DataFrame(data,columns=['Name','Age','score'])

# %%
df
# Out:
#    Name  Age  score
# 0   tom   10     50
# 1  nick   16     58

# %%
df.plot(kind='pie',x='Age',y='Score')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(projection='3d')
# ----> 3 X = np.arange(-5, 5, 0.15)
#       4 Y = np.arange(-5, 5, 0.15)
#       5 X, Y = np.meshgrid(X, Y)
#
# NameError: name 'np' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [28], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(projection='3d')
# ----> 3 X = np.arange(-5, 5, 0.15)
#       4 Y = np.arange(-5, 5, 0.15)
#       5 X, Y = np.meshgrid(X, Y)
#
# NameError: name 'np' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1
                , cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [29], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(projection='3d')
# ----> 3 X = np.arange(-5, 5, 0.15)
#       4 Y = np.arange(-5, 5, 0.15)
#       5 X, Y = np.meshgrid(X, Y)
#
# NameError: name 'np' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = Axes3D(fig)
x = [2, 4, 6, 3, 1]
y = [1, 6, 8, 1, 3]
z = [3, 4, 10, 3, 1]
ax.scatter3D(x, y, z, c=z, alpha=1, marker='d', s=150)
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axes
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
 
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot geeks for geeks')
plt.show()
# Out:
# C:\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
